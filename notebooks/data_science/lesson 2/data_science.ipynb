# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %config InlineBackend.figure_format = 'svg'

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 12, 10

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
data = pd.read_csv('../../data_science/Dataset_games.csv')
data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
data['Year_of_Release'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,   nan, 1995., 1991., 1981., 1987.,
#        1980., 1983., 2020., 2017.])

# %%
data['Year_of_Release'][data['Year_of_Release'].isnull()]
# Out:
# 183     NaN
# 377     NaN
# 456     NaN
# 475     NaN
# 609     NaN
#          ..
# 16376   NaN
# 16409   NaN
# 16452   NaN
# 16462   NaN
# 16526   NaN
# Name: Year_of_Release, Length: 269, dtype: float64

# %%
data[~data['Year_of_Release'].isnull()]
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
data = data.dropna()
data
# Out:
#                                     Name Platform  Year_of_Release     Genre  \
# 0                             Wii Sports      Wii           2006.0    Sports
# 2                         Mario Kart Wii      Wii           2008.0    Racing
# 3                      Wii Sports Resort      Wii           2009.0    Sports
# 6                  New Super Mario Bros.       DS           2006.0  Platform
# 7                               Wii Play      Wii           2006.0      Misc
# ...                                  ...      ...              ...       ...
# 16667         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 16677     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 16700                             Breach       PC           2011.0   Shooter
# 16706            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
data['Year_of_Release'] = data.Year_of_Release.astype('int64')
data['User_Count'] = data.User_Count.astype('int64')
data['Critic_Count'] = data.Critic_Count.astype('int64')
data['User_Score'] = data.User_Score.astype('float64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6825 entries, 0 to 16706
# Data columns (total 16 columns):
# Name               6825 non-null object
# Platform           6825 non-null object
# Year_of_Release    6825 non-null int64
# Genre              6825 non-null object
# Publisher          6825 non-null object
# NA_Sales           6825 non-null float64
# EU_Sales           6825 non-null float64
# JP_Sales           6825 non-null float64
# Other_Sales        6825 non-null float64
# Global_Sales       6825 non-null float64
# Critic_Score       6825 non-null float64
# Critic_Count       6825 non-null int64
# User_Score         6825 non-null float64
# User_Count         6825 non-null int64
# Developer          6825 non-null object
# Rating             6825 non-null object
# dtypes: float64(7), int64(3), object(6)
# memory usage: 906.4+ KB

# %%
cols = ['Global_Sales', 'Critic_Score', 'Critic_Count', 'User_Score', 'User_Count']
sns.pairplot(data[cols])
# Out:
# Error in callback <function flush_figures at 0x0000028468C527B8> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# D:\Software\Anaconda3\envs\dev\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# D:\Software\Anaconda3\envs\dev\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ...

# %%
sns.distplot(data.Critic_Score)

# %%
sns.jointplot(data.Critic_Score, data.User_Score)

# %%
top_platforms = data.Platform.value_counts().sort_values(ascending=False).head(5).index.values

# %%
sns.boxplot(data=data[data.Platform.isin(top_platforms)], x="Critic_Score", y="Platform")

# %%
platform_genre_sales = data.pivot_table(columns='Genre', index='Platform', values='Global_Sales', aggfunc=sum).fillna(0)

# %%
sns.heatmap(platform_genre_sales, annot=True, fmt='.1f', linewidths=.5, cmap='pink')
